# %%
import pandas as pd
from IPython.display import display

# Contoh DataFrame 1
data1 = {"Nama": ["Indra", "Rina", "Budi"], "Umur": [25, 30, 22]}
df1 = pd.DataFrame(data1)

# Contoh DataFrame 2
data2 = {"Kota": ["Jakarta", "Surabaya", "Bandung"], "Penduduk": [10_000, 3_000, 2_500]}
df2 = pd.DataFrame(data2)

# Menampilkan keduanya
display(df1.info(), df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    3 non-null      object
#  1   Umur    3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kota      3 non-null      object
#  1   Penduduk  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# None
# None

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import urllib
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='maroon')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
import pandas as pd

data = pd.DataFrame({
    "geolocation_lng": [-50.0, -40.0, -47.0, -60.0],
    "geolocation_lat": [-10.0, -15.0, -20.0, -5.0]
})

plot_brazil_map(data)
